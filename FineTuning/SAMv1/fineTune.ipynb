# %%
# Essential imports for notebook visualization
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pathlib import Path
import h5py
import json
import os
import sys
import subprocess
import time
from datetime import datetime
from IPython.display import display, HTML, clear_output, Image
import ipywidgets as widgets
from tqdm.notebook import tqdm
import threading
import warnings
warnings.filterwarnings("ignore")

# Configure matplotlib for inline display
# %matplotlib inline
plt.style.use('default')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300

# Check GPU availability
import torch
print(f"🔧 Environment Setup:")
print(f"   PyTorch version: {torch.__version__}")
print(f"   CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
print(f"   Working directory: {os.getcwd()}")
print(f"✅ Environment ready!")

# Display current time
print(f"\n⏰ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# File paths
DATA_PATH = "../../ComplexNeuralNetworks/sassed_V4.h5"
CHECKPOINT_PATH = "../../SAMadapter/sam_checkpoints/sam_vit_l_0b3195.pth"
CONFIG_FILE = "config_vit_l_all.json"

# Verify files exist
files_to_check = {
    "Data file": DATA_PATH,
    "SAM checkpoint": CHECKPOINT_PATH,
    "Training script": "finetune_sam_complex.py"
}

print("📁 File Verification:")
all_files_exist = True
for name, path in files_to_check.items():
    exists = os.path.exists(path)
    status = "✅" if exists else "❌"
    print(f"   {status} {name}: {path}")
    if not exists:
        all_files_exist = False

if not all_files_exist:
    print("⚠️  Some files are missing. Please check the paths above.")
else:
    print("✅ All required files found!")

# Create configuration if it doesn't exist
config = {
    "model_type": "vit_l",
    "freeze_components": [],
    "batch_size": 1,
    "learning_rate": 1e-5,
    "weight_decay": 1e-4,
    "optimizer": "adamw",
    "betas": [0.9, 0.999],
    "num_epochs": 200,
    "scheduler": "cosine",
    "min_lr": 1e-7,
    "focal_weight": 0.5,
    "dice_weight": 0.5,
    "iou_weight": 0,
    "clip_grad_norm": 1.0,
    "checkpoint_dir": "./checkpoints_vit_l_all",
    "save_interval": 10,
    "plot_interval": 10,
    "log_interval": 20
}

# Save configuration
with open(CONFIG_FILE, 'w') as f:
    json.dump(config, f, indent=2)

print(f"\n📄 Configuration saved to: {CONFIG_FILE}")
print(f"📂 Checkpoints will be saved to: {config['checkpoint_dir']}")

# %% [markdown]
# # No Prompt

# %%
# File paths
DATA_PATH = "../../ComplexNeuralNetworks/sassed_V4.h5"
CHECKPOINT_PATH = "../../SAMadapter/sam_checkpoints/sam_vit_l_0b3195.pth"
CONFIG_FILE = "config_vit_l_noPrompt.json"

# Verify files exist
files_to_check = {
    "Data file": DATA_PATH,
    "SAM checkpoint": CHECKPOINT_PATH,
    "Training script": "finetune_sam_complex-noPrompt.py"
}

print("📁 File Verification:")
all_files_exist = True
for name, path in files_to_check.items():
    exists = os.path.exists(path)
    status = "✅" if exists else "❌"
    print(f"   {status} {name}: {path}")
    if not exists:
        all_files_exist = False

if not all_files_exist:
    print("⚠️  Some files are missing. Please check the paths above.")
else:
    print("✅ All required files found!")

# Create configuration if it doesn't exist
config = {
    "model_type": "vit_l",
    "freeze_components": [],
    "batch_size": 1,
    "learning_rate": 1e-5,
    "weight_decay": 1e-4,
    "optimizer": "adamw",
    "betas": [0.9, 0.999],
    "num_epochs": 150,
    "scheduler": "cosine",
    "min_lr": 1e-6,
    "focal_weight": 0.5,
    "dice_weight": 0.5,
    "iou_weight": 0,
    "clip_grad_norm": 1.0,
    "checkpoint_dir": "./checkpoint_vit_l_noPrompt",
    "save_interval": 10,
    "plot_interval": 10,
    "log_interval": 20
}

# Save configuration
with open(CONFIG_FILE, 'w') as f:
    json.dump(config, f, indent=2)

print(f"\n📄 Configuration saved to: {CONFIG_FILE}")
print(f"📂 Checkpoints will be saved to: {config['checkpoint_dir']}")

# Execute the training command with real-time output
import subprocess
import sys
from datetime import datetime

# Training command
cmd = [
    sys.executable, "finetune_sam_complex-noPrompt.py",
    "--data_path", DATA_PATH,
    "--checkpoint", CHECKPOINT_PATH,
    "--config", CONFIG_FILE
]

print("🚀 Starting SAM Fine-tuning...")
print(f"⏰ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("=" * 80)

# Execute command and display output in real-time
try:
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        universal_newlines=True,
        bufsize=1
    )
    
    # Read output line by line
    for line in process.stdout:
        print(line.rstrip())
        # Flush output to ensure real-time display
        sys.stdout.flush()
    
    # Wait for process to complete
    return_code = process.wait()
    
    print("=" * 80)
    if return_code == 0:
        print("✅ Training completed successfully!")
    else:
        print(f"❌ Training failed with return code: {return_code}")
        
    print(f"⏰ Finished at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    
except KeyboardInterrupt:
    print("\n⚠️  Training interrupted by user")
    process.terminate()
    print("🛑 Process terminated")
    
except Exception as e:
    print(f"❌ Error during training: {e}")

print("\n📊 Check the output above for:")
print("   • Real-time loss plots (displayed every 10 epochs)")
print("   • Training progress summaries")
print("   • Checkpoint saving notifications")
print("   • Final training statistics")
# Out:
# 📁 File Verification:
#    ✅ Data file: ../../ComplexNeuralNetworks/sassed_V4.h5
#    ✅ SAM checkpoint: ../../SAMadapter/sam_checkpoints/sam_vit_l_0b3195.pth
#    ✅ Training script: finetune_sam_complex-noPrompt.py
# ✅ All required files found!
#
# 📄 Configuration saved to: config_vit_l_noPrompt.json
# 📂 Checkpoints will be saved to: ./checkpoint_vit_l_noPrompt
# 🚀 Starting SAM Fine-tuning...
# ⏰ Started at: 2025-10-29 13:52:32
# ================================================================================
# 2025-10-29 13:52:44,770 - INFO - Built vit_l model with complex input support
# 2025-10-29 13:52:44,772 - INFO - 📊 Parameter Summary:
# 2025-10-29 13:52:44,772 - INFO -    Total parameters: 312,074,468
# 2025-10-29 13:52:44,772 - INFO -    Trainable parameters: 312,074,468
# 2025-10-29 13:52:44,772 - INFO -    Frozen parameters: 0
# 2025-10-29 13:52:44,772 - INFO -    Trainable ratio: 100.00%
# 2025-10-29 13:52:44,772 - INFO - 🔓 No components frozen - training entire model
# 2025-10-29 13:52:44,772 - INFO - 📋 Parameter breakdown by component:
# 2025-10-29 13:52:44,773 - INFO -    Image Encoder: 308,016,128/308,016,128 trainable
# 2025-10-29 13:52:44,773 - INFO -    Prompt Encoder: 0/0 trainable (disabled)
# 2025-10-29 13:52:44,774 - INFO -    Mask Decoder: 4,058,340/4,058,340 trainable
# 2025-10-29 13:52:44,774 - INFO - Built vit_l model with complex input support
# 2025-10-29 13:52:45,487 - INFO - Built adamw optimizer with lr=1e-05
# 2025-10-29 13:52:45,487 - INFO - Built cosine scheduler
# 2025-10-29 13:52:45,488 - INFO - Starting training...
# 2025-10-29 13:52:45,488 - INFO - Training on 103 samples
# 2025-10-29 13:52:45,488 - INFO - Validation on 26 samples
# 2025-10-29 13:52:45,488 - INFO -
# Epoch 1/150
# ==================================================
# Training Configuration:
# ==================================================
# model_type: vit_l
# pretrained_checkpoint: ../../SAMadapter/sam_checkpoints/sam_vit_l_0b3195.pth
# freeze_components: []
# input_size: 992
# output_size: 992
# augment: True
# prompt_type: click
# train_split: 0.8
# val_split: 0.2
# batch_size: 1
# num_epochs: 150
# learning_rate: 1e-05
# weight_decay: 0.0001
# optimizer: adamw
# betas: [0.9, 0.999]
# scheduler: cosine
# min_lr: 1e-06
# step_size: 30
# gamma: 0.1
# focal_weight: 0.5
# dice_weight: 0.5
# iou_weight: 0
# clip_grad_norm: 1.0
# num_workers: 4
# pin_memory: True
# checkpoint_dir: ./checkpoint_vit_l_noPrompt
# log_interval: 20
# save_interval: 10
# plot_interval: 10
# device: cuda
# ==================================================
# Loading data...
# Original mask value range: [0, 8]
# Unique mask values: [0 1 2 3 4 5 6 7 8]
# After processing mask value range: [0, 8]
# Unique mask values after processing: [0 1 2 3 4 5 6 7 8]
# Loaded 129 samples
# Image shape: (129, 1001, 1001), Mask shape: (129, 1001, 1001)
# Train samples: 103, Val samples: 26
# 2025-10-29 13:53:19,655 - INFO - Epoch 001
# 2025-10-29 13:53:19,656 - INFO - Train - Total: 0.0899 | Dice: 0.1155 | Focal: 0.0644 | mIoU: 0.2608 | Pixel Acc: 0.2170 | Class Pixel Acc: 0.4047
# 2025-10-29 13:53:19,656 - INFO - Val - Total: 0.0314 | Dice: 0.0405 | Focal: 0.0224 | mIoU: 0.0700 | Pixel Acc: 0.0393 | Class Pixel Acc: 0.1499
# 2025-10-29 13:53:32,890 - INFO - Saved best checkpoint at epoch 1 with val_loss 0.0314
# 2025-10-29 13:53:40,853 - INFO - Loss plots saved to checkpoint_vit_l_noPrompt/plots
# 2025-10-29 13:53:40,854 - INFO -
# Epoch 2/150
# 2025-10-29 13:54:13,938 - INFO - Epoch 002
# 2025-10-29 13:54:13,939 - INFO - Train - Total: 0.0551 | Dice: 0.0751 | Focal: 0.0351 | mIoU: 0.3082 | Pixel Acc: 0.2446 | Class Pixel Acc: 0.4457
# 2025-10-29 13:54:13,939 - INFO - Val - Total: 0.0514 | Dice: 0.0672 | Focal: 0.0357 | mIoU: 0.0758 | Pixel Acc: 0.0484 | Class Pixel Acc: 0.1700
# 2025-10-29 13:54:13,939 - INFO -
# Epoch 3/150
# 2025-10-29 13:54:47,173 - INFO - Epoch 003
# 2025-10-29 13:54:47,174 - INFO - Train - Total: 0.0436 | Dice: 0.0604 | Focal: 0.0269 | mIoU: 0.3260 | Pixel Acc: 0.2552 | Class Pixel Acc: 0.4643
# 2025-10-29 14:28:24,215 - INFO - Train - Total: 0.0143 | Dice: 0.0216 | Focal: 0.0070 | mIoU: 0.3772 | Pixel Acc: 0.2705 | Class Pixel Acc: 0.5006
# 2025-10-29 14:28:24,215 - INFO - Val - Total: 0.0622 | Dice: 0.0620 | Focal: 0.0623 | mIoU: 0.0805 | Pixel Acc: 0.0453 | Class Pixel Acc: 0.1646
# 2025-10-29 14:28:38,906 - INFO - Loss plots saved to checkpoint_vit_l_noPrompt/plots
# 2025-10-29 14:28:38,906 - INFO -
# Epoch 61/150
# 2025-10-29 14:29:11,785 - INFO - Epoch 061
# 2025-10-29 14:29:11,786 - INFO - Train - Total: 0.0136 | Dice: 0.0205 | Focal: 0.0068 | mIoU: 0.3809 | Pixel Acc: 0.2755 | Class Pixel Acc: 0.5029
# 2025-10-29 14:29:11,786 - INFO - Val - Total: 0.0514 | Dice: 0.0550 | Focal: 0.0478 | mIoU: 0.0752 | Pixel Acc: 0.0428 | Class Pixel Acc: 0.1547
# 2025-10-29 14:29:11,786 - INFO -
# Epoch 62/150
# 2025-10-29 14:29:44,649 - INFO - Epoch 062
# 2025-10-29 14:29:44,650 - INFO - Train - Total: 0.0134 | Dice: 0.0202 | Focal: 0.0066 | mIoU: 0.3814 | Pixel Acc: 0.2700 | Class Pixel Acc: 0.5038
# 2025-10-29 14:29:44,650 - INFO - Val - Total: 0.0684 | Dice: 0.0657 | Focal: 0.0710 | mIoU: 0.0766 | Pixel Acc: 0.0450 | Class Pixel Acc: 0.1621
# 2025-10-29 14:29:44,650 - INFO -
# Epoch 63/150
#
# ⚠️  Training interrupted by user
# 🛑 Process terminated
#
# 📊 Check the output above for:
#    • Real-time loss plots (displayed every 10 epochs)
#    • Training progress summaries
#    • Checkpoint saving notifications
#    • Final training statistics

# %%
# File paths
DATA_PATH = "../../ComplexNeuralNetworks/sassed_V4.h5"
CHECKPOINT_PATH = "../../SAMadapter/sam_checkpoints/sam_vit_b_01ec64.pth"
"""
SAMadapter/sam_checkpoints/sam_vit_b_01ec64.pth
SAMadapter/sam_checkpoints/sam_vit_h_4b8939.pth
SAMadapter/sam_checkpoints/sam_vit_l_0b3195.pth
"""
CONFIG_FILE = "config_vit_b_noPrompt.json"

# Verify files exist
files_to_check = {
    "Data file": DATA_PATH,
    "SAM checkpoint": CHECKPOINT_PATH,
    "Training script": "finetune_sam_complex-noPrompt.py"
}

print("📁 File Verification:")
all_files_exist = True
for name, path in files_to_check.items():
    exists = os.path.exists(path)
    status = "✅" if exists else "❌"
    print(f"   {status} {name}: {path}")
    if not exists:
        all_files_exist = False

if not all_files_exist:
    print("⚠️  Some files are missing. Please check the paths above.")
else:
    print("✅ All required files found!")

# Create configuration if it doesn't exist
config = {
    "model_type": "vit_b",
    "freeze_components": [],
    "batch_size": 1,
    "learning_rate": 1e-5,
    "weight_decay": 1e-4,
    "optimizer": "adamw",
    "betas": [0.9, 0.999],
    "num_epochs": 150,
    "scheduler": "cosine",
    "min_lr": 1e-6,
    "focal_weight": 0.5,
    "dice_weight": 0.5,
    "iou_weight": 0,
    "clip_grad_norm": 1.0,
    "checkpoint_dir": "./checkpoint_vit_b_noPrompt",
    "save_interval": 10,
    "plot_interval": 10,
    "log_interval": 20
}

# Save configuration
with open(CONFIG_FILE, 'w') as f:
    json.dump(config, f, indent=2)

print(f"\n📄 Configuration saved to: {CONFIG_FILE}")
print(f"📂 Checkpoints will be saved to: {config['checkpoint_dir']}")

# Execute the training command with real-time output
import subprocess
import sys
from datetime import datetime

# Training command
cmd = [
    sys.executable, "finetune_sam_complex-noPrompt.py",
    "--data_path", DATA_PATH,
    "--checkpoint", CHECKPOINT_PATH,
    "--config", CONFIG_FILE
]

print("🚀 Starting SAM Fine-tuning...")
print(f"⏰ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("=" * 80)

# Execute command and display output in real-time
try:
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        universal_newlines=True,
        bufsize=1
    )
    
    # Read output line by line
    for line in process.stdout:
        print(line.rstrip())
        # Flush output to ensure real-time display
        sys.stdout.flush()
    
    # Wait for process to complete
    return_code = process.wait()
    
    print("=" * 80)
    if return_code == 0:
        print("✅ Training completed successfully!")
    else:
        print(f"❌ Training failed with return code: {return_code}")
        
    print(f"⏰ Finished at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    
except KeyboardInterrupt:
    print("\n⚠️  Training interrupted by user")
    process.terminate()
    print("🛑 Process terminated")
    
except Exception as e:
    print(f"❌ Error during training: {e}")

print("\n📊 Check the output above for:")
print("   • Real-time loss plots (displayed every 10 epochs)")
print("   • Training progress summaries")
print("   • Checkpoint saving notifications")
print("   • Final training statistics")
# Out:
# 📁 File Verification:
#    ✅ Data file: ../../ComplexNeuralNetworks/sassed_V4.h5
#    ✅ SAM checkpoint: ../../SAMadapter/sam_checkpoints/sam_vit_b_01ec64.pth
#    ✅ Training script: finetune_sam_complex-noPrompt.py
# ✅ All required files found!
#
# 📄 Configuration saved to: config_vit_b_noPrompt.json
# 📂 Checkpoints will be saved to: ./checkpoint_vit_b_noPrompt
# 🚀 Starting SAM Fine-tuning...
# ⏰ Started at: 2025-10-29 17:15:24
# ================================================================================
# 2025-10-29 17:15:35,911 - INFO - Built vit_b model with complex input support
# 2025-10-29 17:15:35,937 - INFO - 📊 Parameter Summary:
# 2025-10-29 17:15:35,937 - INFO -    Total parameters: 93,532,644
# 2025-10-29 17:15:35,937 - INFO -    Trainable parameters: 93,532,644
# 2025-10-29 17:15:35,937 - INFO -    Frozen parameters: 0
# 2025-10-29 17:15:35,937 - INFO -    Trainable ratio: 100.00%
# 2025-10-29 17:15:35,937 - INFO - 🔓 No components frozen - training entire model
# 2025-10-29 17:15:35,937 - INFO - 📋 Parameter breakdown by component:
# 2025-10-29 17:15:35,939 - INFO -    Image Encoder: 89,474,304/89,474,304 trainable
# 2025-10-29 17:15:35,939 - INFO -    Prompt Encoder: 0/0 trainable (disabled)
# 2025-10-29 17:15:35,939 - INFO -    Mask Decoder: 4,058,340/4,058,340 trainable
# 2025-10-29 17:15:35,939 - INFO - Built vit_b model with complex input support
# 2025-10-29 17:15:36,427 - INFO - Built adamw optimizer with lr=1e-05
# 2025-10-29 17:15:36,428 - INFO - Built cosine scheduler
# 2025-10-29 17:15:36,428 - INFO - Starting training...
# 2025-10-29 17:15:36,429 - INFO - Training on 103 samples
# 2025-10-29 17:15:36,429 - INFO - Validation on 26 samples
# 2025-10-29 17:15:36,429 - INFO -
# Epoch 1/150
# ==================================================
# Training Configuration:
# ==================================================
# model_type: vit_b
# pretrained_checkpoint: ../../SAMadapter/sam_checkpoints/sam_vit_b_01ec64.pth
# freeze_components: []
# input_size: 992
# output_size: 992
# augment: True
# prompt_type: click
# train_split: 0.8
# val_split: 0.2
# batch_size: 1
# num_epochs: 150
# learning_rate: 1e-05
# weight_decay: 0.0001
# optimizer: adamw
# betas: [0.9, 0.999]
# scheduler: cosine
# min_lr: 1e-06
# step_size: 30
# gamma: 0.1
# focal_weight: 0.5
# dice_weight: 0.5
# iou_weight: 0
# clip_grad_norm: 1.0
# num_workers: 4
# pin_memory: True
# checkpoint_dir: ./checkpoint_vit_b_noPrompt
# log_interval: 20
# save_interval: 10
# plot_interval: 10
# device: cuda
# ==================================================
# Loading data...
# Original mask value range: [0, 8]
# Unique mask values: [0 1 2 3 4 5 6 7 8]
# After processing mask value range: [0, 8]
# Unique mask values after processing: [0 1 2 3 4 5 6 7 8]
# Loaded 129 samples
# Image shape: (129, 1001, 1001), Mask shape: (129, 1001, 1001)
# Train samples: 103, Val samples: 26
# 2025-10-29 17:15:54,513 - INFO - Epoch 001
# 2025-10-29 17:15:54,514 - INFO - Train - Total: 0.1953 | Dice: 0.2531 | Focal: 0.1375 | mIoU: 0.2006 | Pixel Acc: 0.1888 | Class Pixel Acc: 0.3329
# 2025-10-29 17:15:54,514 - INFO - Val - Total: 0.0723 | Dice: 0.0950 | Focal: 0.0497 | mIoU: 0.0366 | Pixel Acc: 0.0422 | Class Pixel Acc: 0.1310
# 2025-10-29 17:15:58,179 - INFO - Saved best checkpoint at epoch 1 with val_loss 0.0723
# 2025-10-29 17:16:01,815 - INFO - Loss plots saved to checkpoint_vit_b_noPrompt/plots
# 2025-10-29 17:16:01,815 - INFO -
# Epoch 2/150
# 2025-10-29 17:16:18,703 - INFO - Epoch 002
# 2025-10-29 17:16:18,703 - INFO - Train - Total: 0.0614 | Dice: 0.0794 | Focal: 0.0434 | mIoU: 0.2996 | Pixel Acc: 0.2419 | Class Pixel Acc: 0.4441
# 2025-10-29 17:16:18,703 - INFO - Val - Total: 0.0409 | Dice: 0.0494 | Focal: 0.0324 | mIoU: 0.0476 | Pixel Acc: 0.0349 | Class Pixel Acc: 0.1229
# 2025-10-29 17:16:22,688 - INFO - Saved best checkpoint at epoch 2 with val_loss 0.0409
# 2025-10-29 17:16:27,139 - INFO - Loss plots saved to checkpoint_vit_b_noPrompt/plots
# 2025-10-29 17:16:27,139 - INFO -
# Epoch 3/150
# 2025-10-29 17:16:43,942 - INFO - Epoch 003
# 2025-10-29 17:16:43,942 - INFO - Train - Total: 0.0558 | Dice: 0.0715 | Focal: 0.0401 | mIoU: 0.3102 | Pixel Acc: 0.2482 | Class Pixel Acc: 0.4521
